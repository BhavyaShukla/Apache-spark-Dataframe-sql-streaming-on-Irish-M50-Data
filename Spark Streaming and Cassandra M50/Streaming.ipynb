# %% [markdown]
# # Question 1

# %%
from pyspark.streaming import StreamingContext
from pyspark.sql import SparkSession
spark=SparkSession.builder.getOrCreate()
from pyspark.sql import Row
import time


def save1(time, rdd):
    try:
        df = spark.createDataFrame(rdd.map(\
        lambda row: Row(time=time, vehicle=row[0], count=row[1])))
        df.write.format("org.apache.spark.sql.cassandra")\
        .options(table="q1", keyspace="streaming")\
        .save(mode="append")
    except:
        pass





ssc = StreamingContext(sc, 5)
lines = ssc.textFileStream("/home/bhavya/streaming/")
records=lines.map(lambda line:line.split(","))
q1=records.map(lambda x: ((x[14]),1))
q1=q1.reduceByKey(lambda a,b : a+b)
q1.foreachRDD(save1)
q1.pprint()

ssc.start()
time.sleep(300)
ssc.stop(stopSparkContext=False)
# Out:
# -------------------------------------------
# Time: 2020-05-05 06:13:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 06:13:05
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 06:13:10
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 06:13:15
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 06:13:20
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 06:13:25
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 06:13:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 06:13:35
# -------------------------------------------
#
# ...

# %% [markdown]
# # Question 2

# %%
from pyspark.streaming import StreamingContext
from pyspark.sql import SparkSession
spark=SparkSession.builder.getOrCreate()
from pyspark.sql import Row
import time


def save(time, rdd):
    try:
        df = spark.createDataFrame(rdd.map(\
        lambda row: Row(time=time, vehicle=row[0], count=row[1])))
        df.write.format("org.apache.spark.sql.cassandra")\
        .options(table="q2", keyspace="streaming")\
        .save(mode="append")
    except:
        pass





ssc = StreamingContext(sc, 5)
lines = ssc.textFileStream("file:///home/bhavyamilanshukla/streamlol/")
records=lines.map(lambda line:line.split(","))
q1=records.map(lambda x: ((x[18]),1))
q1=q1.reduceByKey(lambda x,y: x+y )
q1=q1.transform(
    lambda rdd:rdd.sortBy(lambda x:x[1],ascending=False)
)
#q1.foreachRDD(save)
q1.pprint()

ssc.start()
time.sleep(300)
ssc.stop(stopSparkContext=False)
# Out:
# -------------------------------------------
# Time: 2020-05-05 00:54:45
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 00:54:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 00:55:15
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 00:55:20
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 00:55:25
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 00:55:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 00:55:35
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 00:55:40
# -------------------------------------------
# ...

# %% [markdown]
# # Question 3

# %%
from pyspark.streaming import StreamingContext
from pyspark.sql import SparkSession
spark=SparkSession.builder.getOrCreate()
from pyspark.sql import Row
import time


def save3(time, rdd):
    try:
        df = spark.createDataFrame(rdd.map(\
        lambda row: Row(time=time, countersite=row[0], count=row[1])))
        df.write.format("org.apache.spark.sql.cassandra")\
        .options(table="q3", keyspace="streaming")\
        .save(mode="append")
    except:
        pass

ssc = StreamingContext(sc, 5)
lines = ssc.textFileStream("/home/bhavya/streaming/")
records=lines.map(lambda line:line.split(","))
q3=records.map(lambda x: ((x[0]),1))
q3=q3.reduceByKey(lambda x,y: x+y )
q3=q3.transform(
    lambda rdd:rdd.sortBy(lambda x:x[1],ascending=False)
)
q3.foreachRDD(save3)
q3.pprint()

ssc.start()
time.sleep(300)
ssc.stop(stopSparkContext=False)
# Out:
# -------------------------------------------
# Time: 2020-05-05 04:28:25
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 04:28:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 04:28:35
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 04:28:40
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 04:28:45
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 04:28:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 04:28:55
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 04:29:00
# -------------------------------------------
#
# ...

# %% [markdown]
# # Question 4

# %%
from pyspark.streaming import StreamingContext
from pyspark.sql import SparkSession
spark=SparkSession.builder.getOrCreate()
from pyspark.sql import Row
import time


def save4(time, rdd):
    try:
        df = spark.createDataFrame(rdd.map(\
        lambda row: Row(time=time, vehicle=row[0], count=row[1])))
        df.write.format("org.apache.spark.sql.cassandra")\
        .options(table="q4", keyspace="streaming")\
        .save(mode="append")
    except:
        pass

ssc = StreamingContext(sc, 5)
lines = ssc.textFileStream("/home/bhavya/streaming/")
records=lines.map(lambda line:line.split(","))
q4=records.map(lambda x: ((x[14]),1))
q4=q4.filter(lambda x: x[0] == " 'HGV_RIG'" or x[0] == " 'HGV_ART'" )
q4.foreachRDD(save4)
q4.pprint()

ssc.start()
time.sleep(300)
ssc.stop(stopSparkContext=False)
# Out:
# -------------------------------------------
# Time: 2020-05-05 05:15:20
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 05:15:25
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 05:15:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 05:15:35
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 05:15:40
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 05:15:45
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 05:15:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-05 05:15:55
# -------------------------------------------
#
# ...
